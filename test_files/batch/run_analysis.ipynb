# %% [markdown]
# # Droplet Analysis
# 1. Run **Cell 1** once to load modules
# 2. Run **Cell 2** to open the interactive UI — select your file and click **▶ Run**
# 3. Run **Cell 3** after the pipeline finishes to view statistics
#
# > Tip: collapse cells 1 and 3 in JupyterLab (click the blue bar on the left) to keep only the UI visible.

# %%
# Setup — run once
import os, sys
_here = os.getcwd()
if _here not in sys.path:
    sys.path.insert(0, _here)
from droplet_ui import launch_ui, show_analysis
print('Ready.')
# Out:
# Ready.

# %%
S = launch_ui()
# Out:
#     <style>
#     .dui-1f43db {
#         background-color: #1a1a1a !important;
#     }
#     .dui-1f43db .p-Widget,
#     .dui-1f43db .jupyter-widgets,
#     .dui-1f43db .widget-box,
#     .dui-1f43db .widget-hbox,
#     .dui-1f43db .widget-vbox {
#         background: transparent !important;
#         background-color: transparent !important;
#     }
#     .dui-1f43db .widget-label,
#     .dui-1f43db .widget-label-basic,
#     .dui-1f43db label {
#         background: transparent !important;
#         background-color: transparent !important;
#         color: #cccccc !important;
#     }
#     .dui-1f43db .widget-readout {
#         background: #2a2a2a !important;
#         color: #cccccc !important;
#         border: 1px solid #555 !important;
#         min-width: 38px !important;
#     }
#     .dui-1f43db input[type=text],
#     .dui-1f43db input[type=number] {
#         background: #2a2a2a !important;
#         color: #cccccc !important;
#         border: 1px solid #555 !important;
#     }
#     .dui-1f43db select {
#         background: #2a2a2a !important;
#         color: #cccccc !important;
#         border: 1px solid #555 !important;
#     }
#     .dui-1f43db .noUi-target {
#         background: #3a3a3a !important;
#         border-color: #555 !important;
#         box-shadow: none !important;
#     }
#     .dui-1f43db .noUi-connect { background: #4a90d9 !important; }
#     .dui-1f43db .noUi-handle {
#         background: #4a90d9 !important;
#         border-color: #2a6db5 !important;
#         box-shadow: none !important;
#     }
#     .dui-1f43db .widget-hslider,
#     .dui-1f43db .widget-slider { background: transparent !important; }
#     .dui-1f43db hr {
#         border: none !important;
#         border-top: 1px solid #444 !important;
#         margin: 3px 0 !important;
#     }
#     </style>
# HBox(children=(FigureWidget({
#     'data': [],
#     'layout': {'dragmode': 'zoom',
#                'font': {'colo…

# %% [markdown]
# ## Analysis Visualizations
# Run after the pipeline has finished.

# %%
show_analysis(S['df'], S['pixel_size'],
              img_shape=S['norm'].shape if S.get('norm') is not None else None)
# Out:
# Total droplets : 345
# Classes found  : 16/16
# Bright red (0) : 4
# Radius         : 3.20 ± 1.24 µm
# Volume         : 199.51 ± 203.85 µm³
# Any unrel. ch  : 0 (0.0%)
# >1 unrel. ch   : 0 (0.0%)
#
# Counts per class:
#   class  0 :    4  ████
#   class  1 :    4  ████
#   class  2 :   31  ███████████████████████████████
#   class  3 :   26  ██████████████████████████
#   class  4 :   11  ███████████
#   class  5 :   18  ██████████████████
#   class  6 :   28  ████████████████████████████
#   class  7 :   13  █████████████
#   class  8 :   26  ██████████████████████████
#   class  9 :   23  ███████████████████████
#   class 10 :   11  ███████████
#   class 11 :   31  ███████████████████████████████
#   class 12 :    9  █████████
#   class 13 :   34  ██████████████████████████████████
#   class 14 :   30  ██████████████████████████████
#   class 15 :   46  ████████████████████████████████████████
